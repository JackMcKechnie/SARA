# %% [markdown]
# Install required packages

# %%
! pip install --quiet pyterrier[java]
! pip uninstall --quiet -y ir_datasets
! pip install --no-cache-dir --quiet git+https://github.com/JackMcKechnie/ir_datasets.git@sara
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.1/866.1 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.3/208.3 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 20.7 MB/s eta 0:00:00
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Building wheel for cbor (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for ir_datasets (pyproject.toml) ... done

# %%
import requests
import zipfile
import io
import ir_datasets
import pyterrier as pt
import os
import pandas as pd
from tqdm import tqdm
from ir_measures import *

# %% [markdown]
# Get run files

# %%
url = "https://zenodo.org/records/18732768/files/runs.zip?download=1"

# download the zip
response = requests.get(url)
response.raise_for_status()  # stop if download fails

# unzip and extract
with zipfile.ZipFile(io.BytesIO(response.content)) as z:
    z.extractall("./")

print("Downloaded run files and unzipped to ./runs")

# load all runs
names = []
runs = []

files = [f for f in os.listdir("./runs") if "checkpoints" not in f]

for file in tqdm(files, desc="Loading runs"):
    names.append(file)
    runs.append(pt.io.read_results(f"./runs/{file}"))
# Out:
# Downloaded run files and unzipped to ./runs
# Loading runs: 100%|██████████| 59/59 [00:14<00:00,  4.14it/s]

# %% [markdown]
# Run experiment!

# %%
irds = ir_datasets.load("sara")
irds.docs_iter()
irds.qrels_iter()
irds.queries_iter()
qrels = pd.DataFrame(irds.qrels_iter())
dataset = pt.datasets.get_dataset("irds:sara")
qrels["relevance"] = qrels["relevance"].apply(lambda x :  1 if x == 2 else x)
qrels = qrels.rename(columns = {"query_id" : "qid", "doc_id" : "docno", "relevance" : "label"})
# Out:
# [INFO] [starting] building docstore
# [INFO] If you have a local copy of https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/e806b1d5ce35c94cec2899e190db7dd7
# [INFO] [starting] https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1
# docs_iter:   0%|                                      | 0/1702 [00:00<?, ?doc/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 0.0%| 0.00/51.8M [00:00<?, ?B/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 0.0%| 16.4k/51.8M [00:00<05:27, 158kB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 0.1%| 49.2k/51.8M [00:00<03:42, 233kB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 0.2%| 123k/51.8M [00:00<02:14, 385kB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 0.5%| 246k/51.8M [00:00<01:29, 576kB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 1.0%| 532k/51.8M [00:00<00:51, 996kB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 2.1%| 1.08M/51.8M [00:00<00:30, 1.68MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 4.2%| 2.20M/51.8M [00:00<00:16, 2.93MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 8.5%| 4.42M/51.8M [00:00<00:09, 5.15MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 14.9%| 7.71M/51.8M [00:00<00:05, 7.96MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 21.2%| 11.0M/51.8M [00:01<00:04, 9.23MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 27.6%| 14.3M/51.8M [00:01<00:03, 11.0MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 33.9%| 17.6M/51.8M [00:01<00:02, 11.6MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 40.2%| 20.8M/51.8M [00:01<00:02, 12.0MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 46.6%| 24.1M/51.8M [00:01<00:02, 12.4MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 52.9%| 27.4M/51.8M [00:02<00:01, 13.3MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 59.3%| 30.7M/51.8M [00:02<00:01, 14.1MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 65.6%| 34.0M/51.8M [00:02<00:01, 14.3MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 71.9%| 37.3M/51.8M [00:02<00:00, 15.0MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 78.3%| 40.6M/51.8M [00:02<00:00, 15.6MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 84.6%| 43.8M/51.8M [00:02<00:00, 16.1MB/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: 90.9%| 47.1M/51.8M [00:02<00:00, 16.7MB/s]
#
# [INFO] [finished] https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: [00:03] [51.8MB] [17.1MB/s]
# docs_iter:   0%|                                      | 0/1702 [00:03<?, ?doc/s]
# https://zenodo.org/records/18609870/files/sara_combined_docs.zip?download=1: [00:03] [51.8MB] [17.0MB/s]
# docs_iter: 129821doc [00:09, 13592.07doc/s]
# [INFO] [finished] docs_iter: [00:09] [129821doc] [13590.56doc/s]
# [INFO] [finished] building docstore [9.56s]
# [INFO] If you have a local copy of https://raw.githubusercontent.com/JackMcKechnie/SARA/refs/heads/main/combined_qrels.txt, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/39a24d38b4d0e352e7818abd09d6815a
# [INFO] [starting] https://raw.githubusercontent.com/JackMcKechnie/SARA/refs/heads/main/combined_qrels.txt
# [INFO] [finished] https://raw.githubusercontent.com/JackMcKechnie/SARA/refs/heads/main/combined_qrels.txt: [00:00] [20.2MB] [109MB/s]

# %%
exp = pt.Experiment(
    runs,
    dataset.get_topics(),
    qrels,
    eval_metrics=[nDCG@10, MRR, P@10, R@100],
    names = names,
    round = 4,
    verbose = True
)
# Out:
# [INFO] If you have a local copy of https://raw.githubusercontent.com/JackMcKechnie/SARA-A-Collection-of-Sensitivity-Aware-Relevance-Assessments/main/repeated_queries.tsv, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/fc0247928a0b93bb344068fa238a5e3f
# [INFO] [starting] https://raw.githubusercontent.com/JackMcKechnie/SARA-A-Collection-of-Sensitivity-Aware-Relevance-Assessments/main/repeated_queries.tsv
# [INFO] [finished] https://raw.githubusercontent.com/JackMcKechnie/SARA-A-Collection-of-Sensitivity-Aware-Relevance-Assessments/main/repeated_queries.tsv: [00:00] [8.19kB] [12.5MB/s]
# pt.Experiment:   0%|          | 0/59 [00:00<?, ?system/s]

# %%
exp
# Out:
#                                                  name      RR    P@10   R@100  \
# 0                        bm25_1000_terrier_minilm.run  0.8165  0.6513  0.0664
# 1                      bm25_1000_terrier_monobert.run  0.7974  0.6727  0.0672
# 2              tctcolbert_1000_npretriever_monot5.run  0.8492  0.7253  0.0753
# 3                         pl2_1000_terrier_monot5.run  0.8281  0.7073  0.0732
# 4                    ance_1000_npretriever_monot5.run  0.8617  0.7180  0.0709
# 5               retromae_1000_npretriever_electra.run  0.8519  0.7160  0.0730
# 6                                pl2_1000_terrier.run  0.6923  0.5093  0.0503
# 7                        bm25_1000_terrier_monot5.run  0.8251  0.6887  0.0721
# 8                       retromae_1000_npretriever.run  0.7784  0.5567  0.0503
# 9              retromae_1000_npretriever_monobert.run  0.8058  0.6907  0.0690
# 10                        dph_1000_terrier_monot5.run  0.8399  0.7093  0.0748
# 11                            e5_1000_npretriever.run  0.8038  0.6147  0.0638
# 12        naver_splade_v2_distil_1000_npretriever.run  0.7833  0.6273  0.0604
# 13                   tasb_1000_npretriever_monot5.run  0.8510  0.7387  0.0766
# 14                           dph_bo1_1000_terrier.run  0.7215  0.5607  0.0587
# 15                           pl2_rm3_1000_terrier.run  0.6588  0.5140  0.0546
# 16  naver_splade_cocondenser_selfdistil_1000_npret...  0.8073  0.6433  0.0614
# 17                           bm25_kl_1000_terrier.run  0.6961  0.5253  0.0568
# 18                           dph_rm3_1000_terrier.run  0.7207  0.5567  0.0569
# 19                      bm25_1000_terrier_electra.run  0.8306  0.6740  0.0718
# 20                               dph_1000_terrier.run  0.7211  0.5420  0.0526
# 21                  ance_1000_npretriever_electra.run  0.8400  0.6980  0.0700
# 22               naver_splade_v3_1000_npretriever.run  0.7950  0.6560  0.0634
# 23                            dph_kl_1000_terrier.run  0.7190  0.5640  0.0586
# 24                  tasb_1000_npretriever_electra.run  0.8669  0.7240  0.0748
# 25                          tasb_1000_npretriever.run  0.6759  0.5347  0.0581
# 26                   ance_1000_npretriever_minilm.run  0.8396  0.6467  0.0621
# 27                 ance_1000_npretriever_monobert.run  0.8070  0.6800  0.0642
# 28  bm25_1000_terrier_castorini_rank_vicuna_7b_v1.run  0.8642  0.6933  0.0511
# 29           tctcolbert_1000_npretriever_monobert.run  0.8048  0.6760  0.0681
# 30  bm25_1000_terrier_castorini_rank_zephyr_7b_v1_...  0.9053  0.7087  0.0511
# 31                          ance_1000_npretriever.run  0.7201  0.5307  0.0484
# 32                      tfidf_1000_terrier_monot5.run  0.8323  0.7040  0.0748
# 33               retromae_1000_npretriever_minilm.run  0.8223  0.6447  0.0638
# 34                     tfidf_1000_terrier_electra.run  0.8455  0.6827  0.0730
# 35                         tfidf_rm3_1000_terrier.run  0.6853  0.5773  0.0593
# 36             tctcolbert_1000_npretriever_minilm.run  0.8381  0.6433  0.0658
# 37                 tasb_1000_npretriever_monobert.run  0.7937  0.6720  0.0696
# 38                    tctcolbert_1000_npretriever.run  0.7953  0.5933  0.0570
# 39                        pl2_1000_terrier_minilm.run  0.8201  0.6553  0.0659
# 40  bm25_1000_terrier_castorini_rankllama-v1-7b-lo...  0.8203  0.6633  0.0660
# 41                      dph_1000_terrier_monobert.run  0.8006  0.6727  0.0680
# 42                       dph_1000_terrier_electra.run  0.8454  0.6847  0.0723
# 43               retromae_1000_npretriever_monot5.run  0.8699  0.7287  0.0742
# 44                          bm25_rm3_1000_terrier.run  0.6699  0.5213  0.0553
# 45                    tfidf_1000_terrier_monobert.run  0.7986  0.6700  0.0679
# 46                             tfidf_1000_terrier.run  0.7291  0.5600  0.0544
# 47                              bm25_1000_terrier.run  0.7044  0.5160  0.0511
# 48                      pl2_1000_terrier_monobert.run  0.7975  0.6660  0.0667
# 49                   tasb_1000_npretriever_minilm.run  0.8277  0.6460  0.0654
# 50                      tfidf_1000_terrier_minilm.run  0.8351  0.6507  0.0663
# 51                        dph_1000_terrier_minilm.run  0.8333  0.6533  0.0662
# 52                          tfidf_kl_1000_terrier.run  0.7088  0.5607  0.0600
# 53                           pl2_bo1_1000_terrier.run  0.6779  0.5040  0.0556
# 54                       pl2_1000_terrier_electra.run  0.8446  0.6767  0.0713
# 55                         tfidf_bo1_1000_terrier.run  0.7134  0.5593  0.0597
# 56                          bm25_bo1_1000_terrier.run  0.7023  0.5253  0.0569
# 57            tctcolbert_1000_npretriever_electra.run  0.8726  0.7307  0.0740
# 58                            pl2_kl_1000_terrier.run  0.6658  0.5113  0.0557
#
#     nDCG@10
# 0    0.6666
# 1    0.6785
# 2    0.7363
# 3    0.7168
# 4    0.7350
# 5    0.7243
# 6    0.5167
# 7    0.7002
# 8    0.5774
# 9    0.6935
# 10   0.7221
# 11   0.6300
# 12   0.6390
# 13   0.7466
# 14   0.5712
# 15   0.5214
# 16   0.6567
# 17   0.5354
# 18   0.5667
# 19   0.6875
# 20   0.5527
# 21   0.7133
# 22   0.6661
# 23   0.5735
# 24   0.7366
# 25   0.5347
# 26   0.6691
# 27   0.6884
# 28   0.7161
# 29   0.6810
# 30   0.7429
# 31   0.5481
# 32   0.7170
# 33   0.6604
# 34   0.6971
# 35   0.5792
# 36   0.6647
# 37   0.6779
# 38   0.6161
# 39   0.6700
# 40   0.6792
# 41   0.6792
# 42   0.7002
# 43   0.7406
# 44   0.5302
# 45   0.6769
# 46   0.5702
# 47   0.5254
# 48   0.6741
# 49   0.6646
# 50   0.6689
# 51   0.6711
# 52   0.5707
# 53   0.5134
# 54   0.6934
# 55   0.5701
# 56   0.5369
# 57   0.7449
# 58   0.5165

# %% [markdown]
# Let's search for ourselves, rather than using a run file. We can use pre-built huggingface indices for this:

# %%
index = pt.Artifact.from_hf('JackMcKechnie/sara.terrier')
bm25 = index.bm25() >> pt.apply.generic(lambda run: run.merge(pd.DataFrame(irds.docs_iter()), left_on="docno", right_on = "doc_id", how="left"))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# https://huggingface.co/datasets/JackMcKechnie/sara.terrier/resolve/main/artifact.tar.lz4:   0%|          | 0.0…
# extracting data.direct.bf [12.8 MB]
# extracting data.document.fsarrayfile [2.1 MB]
# extracting data.inverted.bf [12.2 MB]
# extracting data.lexicon.fsomapfile [13.1 MB]
# extracting data.lexicon.fsomaphash [1017 B]
# extracting data.lexicon.fsomapid [626.2 KB]
# extracting data.meta-0.fsomapfile [8.0 MB]
# extracting data.meta.idx [1014.2 KB]
# extracting data.meta.zdata [4.1 MB]
# extracting data.properties [4.2 KB]
# extracting pt_meta.json [79 B]
# terrier-assemblies 5.11 jar-with-dependencies not found, downloading to /root/.pyterrier...
# https://repo1.maven.org/maven2/org/terrier/terrier-assemblies/5.11/terrier-assemblies-5.11-jar-with-dependenci…
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# https://repo1.maven.org/maven2/org/terrier/terrier-python-helper/0.0.8/terrier-python-helper-0.0.8.jar:   0%| …
# Done
# Java started (triggered by Retriever.__init__) and loaded: pyterrier.java.colab, pyterrier.java, pyterrier.java.24, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]

# %%
bm25.search("California energy crisis").iloc[0]["text"]
# Out:
# 'Observations on the California Energy Crisis The White House Writers Group January 31st Gray Davis has announced that he will soon announce two energy czars to lead the state through the current crisis. ?Logical candidates include: Laurel and Hardy, Abbott and Costello, Beavis and Butthead, and Siegfried and Roy. The environmentalist Green Party is well-named. ?Thanks to its role in blocking construction of new power plants, Californians are forking over plenty of green for energy. California?s power industry is very Kennedyesque. ?Their message to consumers is, "Ask not what your energy company can do for you; ask what you can do for your energy company." Congress might get involved in California?s energy crisis. ?There?s nothing a drowning victim needs more than having an anchor thrown to him. It?s one thing for California politicians trying to solve the energy problem to go back to the drawing board, but do they have to ask taxpayers to buy them a new one? In California, lawmakers are now getting down to details. ?The latest debate involves what to name the bonds the state will issue to help bail out the utilities. ?Proposals on the table include: ?Blackout Bonds;Bailout Bonds; Davis Debts; Blunder Bonds; Fiasco Funds. ###'

# %%
bm25.search("Accounting fraud").iloc[0]["text"]
# Out:
# "Just to let you know. Fraud just called me about the case. they have received the paperwork and they are ready to credit the full amount to the account however instead I 'm going ot debit new account for $4504.30. And tomorrow fraud will credit new account for the same amount. This way we do not have to open the old account. In other words we trying to minimixe exposure as possible and follow procedures. again your account will be debited only temp. I wanted to share that with you in case you see it on your statement. any questions please call me yours, ameer. >>> <John.Griffith@enron.com> 03/19/01 01:49PM >>> I am sorry I haven't been by. I will come by this evening. Thanks for everything. John"
